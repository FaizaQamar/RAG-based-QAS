# %%
# !pip install evaluate
# !pip install bert_score
# !pip install openpyxl

# %%
import pandas as pd

# %%
df = pd.read_excel('/content/drive/MyDrive/Umrah/Evaluation.xlsx')
print(list(df['website']))
# Out:
# ['Umrah means “to visit a populated place“ . It is a pilgrimage to Makkah and a Sunnah of Prophet Mohammad pbuh.', 'Steps for Umrah:\nIhram – Intention to perform Umrah\nTawaf around the Holy Kaaba\nSai’I – Seven rounds between mount Safa and Mawrah in worship\nCut hair – Men must trim or shave their hair, women must trim their hair (cut the tip)', 'Hajj is pillar of Islam and Umrah is Sunnah.\nHajjj is only performed in the month of Zil Hajj and Umrah can be performed through out the year.\nHajj consists of Ihram, Tawaf, Sai, Halq/Taqsir, Mina, Arafat, stoning shaitan, Muzdalifah and Qurbani whereas Umrah consists of Ihram, Tawaf, Sai and Halq/Taqsir', 'Yes, al muslim foreigners from any country in the world are allowed to perform Umrah', 'No, Non-Muslims are not allowed to enter Makkah or Madinah cities.', 'Ihram is the sacred stated in which it is obligatory for a Muslim to enter to perform Hajj or Umrah.', 'One can do the Niyat of Ihram while leaving from home or at the airport o
# ...

# %%
from evaluate import load
bertscore = load("bertscore")
predictions = ["hello there", "general kenobi"]
references = ["hello there", "general kenobi"]
results = bertscore.compute(predictions=predictions, references=references, lang="en")
# Out:
# ...
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/482 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# ...

# %%
results
# Out:
# {'precision': [1.0, 1.0],
#  'recall': [1.0, 1.0],
#  'f1': [1.0, 1.0],
#  'hashcode': 'roberta-large_L17_no-idf_version=0.3.12(hug_trans=4.38.2)'}

# %%
from evaluate import load
bertscore = load("bertscore")
predictions = list(df['hz'])
references = list(df['website'])
results = bertscore.compute(predictions=predictions, references=references, lang="en")
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# Quran GPT

# %%
from evaluate import load
bertscore = load("bertscore")
predictions = list(df['QuranGPT'])
references = list(df['website'])
results = bertscore.compute(predictions=predictions, references=references, lang="en")
p = sum(results['precision'])/len(results['precision'])
print(p)
recall = sum(results['recall'])/len(results['recall'])
print(recall)
f1 = sum(results['f1'])/len(results['f1'])
print(f1)
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 0.8391331759366122
# 0.8705413341522217
# 0.85425311868841

# %% [markdown]
# Salam Chat

# %%
from evaluate import load
bertscore = load("bertscore")
predictions = list(df['SalamChat'])
references = list(df['website'])
results = bertscore.compute(predictions=predictions, references=references, lang="en")
p = sum(results['precision'])/len(results['precision'])
print(p)
recall = sum(results['recall'])/len(results['recall'])
print(recall)
f1 = sum(results['f1'])/len(results['f1'])
print(f1)
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 0.8299095684831793
# 0.8717660524628379
# 0.8500725626945496

# %% [markdown]
# Islam and AI

# %%
predictions = list(df['Islam and AI'])
references = list(df['website'])
results = bertscore.compute(predictions=predictions, references=references, lang="en")
p = sum(results['precision'])/len(results['precision'])
print(p)
recall = sum(results['recall'])/len(results['recall'])
print(recall)
f1 = sum(results['f1'])/len(results['f1'])
print(f1)
# Out:
# 0.8175745768980547
# 0.8701799999583851
# 0.8428844755346124

# %%
p = sum(results['precision'])/len(results['precision'])
print(p)
# Out:
# 0.8377622745253823

# %%
recall = sum(results['recall'])/len(results['recall'])
print(recall)
# Out:
# 0.8825191096826033

# %%
f1 = sum(results['f1'])/len(results['f1'])
print(f1)
# Out:
# 0.8593655499545011

# %%
results
# Out:
# {'precision': [0.8223522305488586,
#   0.8270711302757263,
#   0.8192192912101746,
#   0.8282962441444397,
#   0.8228462934494019,
#   0.8322531580924988,
#   0.863572359085083,
#   0.8609413504600525,
#   0.8217206001281738,
#   0.8485521078109741,
#   0.868560254573822],
#  'recall': [0.8464179635047913,
#   0.8442051410675049,
#   0.844518780708313,
#   0.9005479216575623,
#   0.9274167418479919,
#   0.8805223107337952,
#   0.8773698806762695,
#   0.8883939981460571,
#   0.8845073580741882,
#   0.9005895853042603,
#   0.9132205247879028],
#  'f1': [0.834211528301239,
#   0.8355502486228943,
#   0.831676721572876,
#   0.8629123568534851,
#   0.8720077276229858,
#   0.855707585811615,
#   0.8704164624214172,
#   0.8744522929191589,
#   0.851958692073822,
#   0.8737967610359192,
#   0.8903306722640991],
#  'hashcode': 'roberta-large_L17_no-idf_version=0.3.12(hug_trans=4.38.2)'}

# %%
# !pip install ragas

# %%
#similarityCheck
import pandas as pd

# Load the CSV
#file_path = '/content/drive/MyDrive/pdf_queryloop/Q&A Bank-Final.csv'
#df = pd.read_csv(file_path)

# Initialize the dictionary structure
data_samples = {
    'question': [],
    'answer': [],
    # 'contexts': [],
    'ground_truth': []
}


for index, row in df.iterrows():
    # Append question, answer (GoldAnswer), and ground_truth (response) from the row
    data_samples['question'].append(row['Question'])
    data_samples['answer'].append(row['Islam and AI'])  # Using 'GoldAnswer' as the answer column name
    data_samples['ground_truth'].append(row['website'])  # Using 'response' as the ground_truth column name

    # # Collect contexts from 'source1' and 'source2' columns, ensuring non-NaN values are added
    # contexts = [row[col] for col in ['source 1', 'source 2'] if pd.notna(row[col])]
    # data_samples['contexts'].append(contexts)

# Display the constructed dictionary or proceed with further processing as needed
print(data_samples)
# Out:
# {'question': ['What is Umrah?', '\xa0What Are The Rituals Of Umrah ?The Acts Performed By Worshippers In The Masjid Al Haram (Holy Kaaba) Are The Rituals Of Umrah.', '\xa0What Is Difference Between Umrah And Hajj ?', '\xa0Are Foreigners Allowed For Umrah ?', '\xa0Are Non-Muslims Allowed To Visit Makkah Or Madinah ?', '\xa0What Is Ihram ?', '\xa0When Should I Do My Umrah Niyat ?', '\xa0Can I Book Umrah Package Online ?', '\xa0What Visa I Require To Perform Umrah ?', '\xa0How Much Time Does It Take To Get The Visa ?', '\xa0How Many Hours It Takes To Perform Umrah?'], 'answer': ['"Umrah" is an Islamic pilgrimage to the holy city of Mecca that can be undertaken at any time of the year, unlike Hajj which has specific dates. It is sometimes called the "lesser pilgrimage" compared to Hajj, which is a mandatory pilgrimage for every able-bodied Muslim who can afford it.\n\nThe performance of Umrah involves specific rituals such as wearing the ihram (a simple, white garment), performing Tawaf 
# ...

# %%
# !pip install datasets

# %%
from datasets import Dataset
# Create the dataset
IslamAIdataset = Dataset.from_dict(data_samples)

# %%
score = evaluate(IslamAIdataset,metrics=[answer_similarity])
score.to_pandas()
# Out:
# Evaluating:   0%|          | 0/11 [00:00<?, ?it/s]
#                                              question  \
# 0                                      What is Umrah?
# 1    What Are The Rituals Of Umrah ?The Acts Perfo...
# 2         What Is Difference Between Umrah And Hajj ?
# 3                  Are Foreigners Allowed For Umrah ?
# 4    Are Non-Muslims Allowed To Visit Makkah Or Ma...
# 5                                     What Is Ihram ?
# 6                   When Should I Do My Umrah Niyat ?
# 7                   Can I Book Umrah Package Online ?
# 8              What Visa I Require To Perform Umrah ?
# 9        How Much Time Does It Take To Get The Visa ?
# 10          How Many Hours It Takes To Perform Umrah?
#
#                                                answer  \
# 0   "Umrah" is an Islamic pilgrimage to the holy c...
# 1   The rituals of Umrah include the following act...
# 2   Foreigners are generally allowed to perform Um...
# ...

# %%
from ragas.metrics import answer_similarity
from ragas import evaluate

score = evaluate(SalamChatdataset,metrics=[answer_similarity])
score.to_pandas()
# Out:
# Evaluating:   0%|          | 0/11 [00:00<?, ?it/s]
#                                              question  \
# 0                                      What is Umrah?
# 1    What Are The Rituals Of Umrah ?The Acts Perfo...
# 2         What Is Difference Between Umrah And Hajj ?
# 3                  Are Foreigners Allowed For Umrah ?
# 4    Are Non-Muslims Allowed To Visit Makkah Or Ma...
# 5                                     What Is Ihram ?
# 6                   When Should I Do My Umrah Niyat ?
# 7                   Can I Book Umrah Package Online ?
# 8              What Visa I Require To Perform Umrah ?
# 9        How Much Time Does It Take To Get The Visa ?
# 10          How Many Hours It Takes To Perform Umrah?
#
#                                                answer  \
# 0   The term "Umrah" or "minor pilgrimage" is not ...
# 1   The rituals and acts performed during Umrah ar...
# 2   In the Quran, there is no specific distinction...
# ...

# %%
# !pip uninstall openai -y
# !pip install openai==0.28.1

import os
# os.environ["OPENAI_API_KEY"] = "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"
# os.environ["OPENAI_API_KEY"] = "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"
os.environ["OPENAI_API_KEY"] = "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"

# %%
avg = sum(score['answer_similarity'])/11
print(avg)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-f17e13c7f04a> in <cell line: 1>()
# ----> 1 avg = sum(score['answer_similarity'])/11
#       2 print(avg)
#
# TypeError: 'numpy.float64' object is not iterable

# %%
from ragas.metrics import (
    answer_relevancy,
    faithfulness,
    context_recall,
    context_precision,
)

# %%
dataset
# Out:
# Dataset({
#     features: ['question', 'answer', 'ground_truth'],
#     num_rows: 11
# })

# %%
from datasets import Dataset

data_samples = {
    'question': ['When was the first super bowl?', 'Who won the most super bowls?'],
    'answer': ['The first superbowl was held on January 15, 1967', 'The most super bowls have been won by The New England Patriots'],
    'contexts' : [['The Super Bowl....season since 1966,','replacing the NFL...in February.'],
    ['The Green Bay Packers...Green Bay, Wisconsin.','The Packers compete...Football Conference']],
    'ground_truth': ['The first superbowl was held on January 15, 1967', 'The New England Patriots have won the Super Bowl a record six times']
}
dataset = Dataset.from_dict(data_samples)

# %%
from ragas import evaluate

result = evaluate(
    dataset,
    metrics=[
        answer_relevancy,
        faithfulness,
        context_recall,
        context_precision,
    ],
)

result
# Out:
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
# {'answer_relevancy': 0.9619, 'faithfulness': 0.0000, 'context_recall': 0.0000, 'context_precision': 0.5000}

# %%
dataset
# Out:
# Dataset({
#     features: ['question', 'answer', 'contexts', 'ground_truth'],
#     num_rows: 2
# })

# %%
from ragas import evaluate

result = evaluate(
    QuranGPTdataset,
    metrics=[
        context_precision,
    ],
)

result
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-8dd3c13b68ad> in <cell line: 3>()
#       1 from ragas import evaluate
#       2
# ----> 3 result = evaluate(
#       4     QuranGPTdataset,
#       5     metrics=[
#
# /usr/local/lib/python3.10/dist-packages/ragas/evaluation.py in evaluate(dataset, metrics, llm, embeddings, callbacks, is_async, run_config, raise_exceptions, column_map)
#     144     # validation
#     145     dataset = handle_deprecated_ground_truths(dataset)
# --> 146     validate_evaluation_modes(dataset, metrics)
#     147     validate_column_dtypes(dataset)
#     148
#
# /usr/local/lib/python3.10/dist-packages/ragas/validation.py in validate_evaluation_modes(ds, metrics)
#      92                 extra_msg = "Looks like you're trying to use 'context_precision' without ground_truth. Please use consider using  `context_utilization' instead."
# ...

# %%
from ragas import evaluate

result = evaluate(
    dataset,
    metrics=[
        answer_relevancy,
        faithfulness,
        context_recall,
        context_precision,
    ],
)

result

# %%
eval_answers = list(df['hz'])
eval_questions = list(df['Question'])

# %%
#from ragas.llama_index import evaluate
from ragas.metrics.critique import harmfulness
result = evaluate(query_engine, metrics, eval_questions, eval_answers)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-2ad586cc6fab> in <cell line: 3>()
#       1 #from ragas.llama_index import evaluate
#       2 from ragas.metrics.critique import harmfulness
# ----> 3 result = evaluate(query_engine, metrics, eval_questions, eval_answers)
#
# NameError: name 'query_engine' is not defined

# %%
# !pip install nest-asyncio
import nest_asyncio
nest_asyncio.apply()

from ragas.metrics import (
    faithfulness,
    answer_relevancy,
    context_precision,
    context_recall,
)
from ragas.metrics.critique import harmfulness

metrics = [
    context_recall,
    answer_relevancy,
    context_precision
    faithfulness,
]
#evaluated question answers
result = evaluate(raw_query_engine, metrics, eval_questions[:15], eval_answers)
# result = evaluate(query_engine, metrics, eval_questions, eval_answers)
